# %% [markdown]
# # Learner algorithm for RC-dependencies, trigrams of container nodes

# %% [markdown]
# Loading in the data and the required packages:

# %%
import math
import numpy
import pandas as pd
from nltk.util import ngrams
from nltk.probability import FreqDist
from learner_functions import get_ngrams, get_freq_dist, get_prob, plot_log_prob_simple

# %%
path = "../data/output_rc_corrected_oct23.xlsx"
data = pd.read_excel(path)

# %%
data.head(10)
# Out:
#    Sent_id           Graph_id  Web_id  \
# 0  s407343  s1245_690_c_11862    1245
# 1  s308196  s145_221_c_309782     145
# 2  s189044     s810_13_c_9831     810
# 3  s381049   s2363_75_c_17545    2363
# 4  s336298     s593_13_c_4944     593
# 5  s346605     s224_31_c_8996     224
# 6  s315396     s623_10_c_8141     623
# 7  s310398  s2347_188_c_88274    2347
# 8  s441019    s81_478_c_16047      81
# 9  s230425     s2498_0_c_4167    2498
#
#                                             Sentence  \
# 0  En dag som vi alle var samlet sammen med menne...
# 1  Dagen etter at lady Helena var kommet tilbake ...
# 2  Hun het Gudrun til fornavn, og så står datoen ...
# 3  Om Silje kjenner det som hun svikter Zorba da ...
# 4                 Nå tenker jeg du gjør som vi sier!
# 5  Hun gjorde en pause, som hun alltid gjorde når...
# 6  Et øyeblikk senere stod Kevin på samme plass s...
# 7  Men nå som det ikke er noen som helst grunn fo...
# 8  'Foreldrene mine blir så rare hver gang det er...
# 9               Men det var ikke derfor hun slikket.
#
#                                            All_paths Chosen_path  \
# 0                    ['TOPIC-REL', 'ADJUNCT $ SUBJ']     ADJUNCT
# 1                    ['TOPIC-REL', 'ADJUNCT $ SUBJ']     ADJUNCT
# 2                    ['TOPIC-REL', 'ADJUNCT $ SUBJ']     ADJUNCT
# 3                 ['TOPIC-REL', 'ADJUNCT $_adv OBJ']     ADJUNCT
# 4                 ['TOPIC-REL', 'ADJUNCT $_adv OBJ']     ADJUNCT
# 5                 ['TOPIC-REL', 'ADJUNCT $_adv OBJ']     ADJUNCT
# 6                 ['TOPIC-REL', 'ADJUNCT $_adv OBJ']     ADJUNCT
# 7                   ['TOPIC-REL', 'COMP_wh-int OBJ']     ADJUNCT
# 8             ['TOPIC-REL', 'FOCUS PREDLINK OBL-TH']     ADJUNCT
# 9  ['TOPIC-REL', 'GVN-TOP_nominal COMP_nominal OBJ']     ADJUNCT
#
#             Comment
# 0  MANUALLY CHECKED
# 1  MANUALLY CHECKED
# 2  MANUALLY CHECKED
# 3  MANUALLY CHECKED
# 4  MANUALLY CHECKED
# 5  MANUALLY CHECKED
# 6  MANUALLY CHECKED
# 7  MANUALLY CHECKED
# 8  MANUALLY CHECKED
# 9  MANUALLY CHECKED

# %% [markdown]
# ## Splitting the data into trigrams and calculating the probabilities of test structures
# ### See RC_bigram for data exploration

# %%
# Set n-gram window size
n_gram = 3

# %%
all_ngrams = []
for string in data['Chosen_path']:
    seq = str(string).split()
    n_grams = get_ngrams(seq, n_gram)
    for ngr in n_grams:
        all_ngrams.append(ngr)
                
freq_dist = get_freq_dist(all_ngrams)
print('20 most common container node n-grams:')
for i in freq_dist.most_common(20):
    print(i)
# Out:
# 20 most common container node n-grams:
# (('start', 'SUBJ', 'end'), 16418)
# (('start', 'OBJ', 'end'), 7934)
# (('XCOMP', 'OBJ', 'end'), 4758)
# (('XCOMP', 'SUBJ', 'end'), 4755)
# (('start', 'XCOMP', 'SUBJ'), 4694)
# (('start', 'XCOMP', 'OBJ'), 4465)
# (('ADJUNCT', 'OBJ', 'end'), 2483)
# (('start', 'ADJUNCT', 'OBJ'), 1642)
# (('start', 'OBL-TH', 'end'), 1028)
# (('start', 'PREDLINK', 'end'), 1010)
# (('XCOMP', 'ADJUNCT', 'OBJ'), 743)
# (('start', 'XCOMP', 'ADJUNCT'), 710)
# (('start', 'ADJUNCT', 'end'), 611)
# (('XCOMP', 'OBL-TH', 'end'), 561)
# (('start', 'XCOMP', 'OBL-TH'), 519)
# (('start', 'XCOMP', 'XCOMP'), 376)
# (('start', 'XCOMP', 'PREDLINK'), 288)
# (('PREDLINK', 'OBL-TH', 'end'), 225)
# (('XCOMP', 'PREDLINK', 'end'), 220)
# (('XCOMP', 'XCOMP', 'OBJ'), 212)

# %% [markdown]
# ## Now we start exploring the modeling results by island type
# ### 1. Subject island

# %% [markdown]
# Plotting the modelled probabilities for four experimental conditions from the Sprouse's design

# %%
# get_prob returns the probability for a path, the path itself, and a list of unattested n-grams
p_short_1, path1, un1 = get_prob(['SUBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['SUBJ'], freq_dist, n_gram)  # short island
# Out:
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'SUBJ', 'end'] -1.2266393253777552

# %%
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'SUBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['COMP_nominal', 'SUBJ', 'ADJUNCT', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'COMP_nominal', 'SUBJ', 'end'] -16.68241964510876
#
# ['start', 'COMP_nominal', 'SUBJ', 'ADJUNCT', 'OBJ', 'end'] -34.85773660000961

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "Subject island")

# %%
condition = []
paths = [" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)]
probs = [p_short_1, p_short_2, p_long_1, p_long_2]
unattested = [un1, un2, un3, un4]
condition.extend(["Subject"]*4)

# %%
unattested
# Out:
# [[], [], [], [('COMP_nominal', 'SUBJ', 'ADJUNCT'), ('SUBJ', 'ADJUNCT', 'OBJ')]]

# %% [markdown]
# ### 2. CNP island (reported in the Appendix)

# %%
# Short conditions are the same as previously
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'OBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['OBJ', 'COMP_nominal', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'COMP_nominal', 'OBJ', 'end'] -12.927042247861705
#
# ['start', 'OBJ', 'COMP_nominal', 'OBJ', 'end'] -29.646742981429995

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "CNP island")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["CNP"]*4)

# %% [markdown]
# ### 3. EQ island (comp_wh-int), subject extraction

# %%
# Short conditions as defined previously
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'SUBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['COMP_wh-int', 'SUBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'COMP_nominal', 'SUBJ', 'end'] -16.68241964510876
#
# ['start', 'COMP_wh-int', 'SUBJ', 'end'] -15.688181397108687

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "EQ island, subject")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["EQ"]*4)

# %% [markdown]
# ### 4. EQ island (comp_wh-int), object extraction (reported in the Appendix)

# %%
p_short_1, path1, un1 = get_prob(['OBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['OBJ'], freq_dist, n_gram)  # short island
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'OBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['COMP_wh-int', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'OBJ', 'end'] -1.9538277331986844
#
# ['start', 'OBJ', 'end'] -1.9538277331986844
#
# ['start', 'COMP_nominal', 'OBJ', 'end'] -12.927042247861705
#
# ['start', 'COMP_wh-int', 'OBJ', 'end'] -22.153288776854943

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "EQ island, object")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["EQ-object"]*4)

# %% [markdown]
# ### 5. Whether island (comp_pol-int), subject extraction (reported in the Appendix)

# %%
p_short_1, path1, un1 = get_prob(['SUBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['SUBJ'], freq_dist, n_gram)  # short island
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'SUBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['COMP_pol-int', 'SUBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'COMP_nominal', 'SUBJ', 'end'] -16.68241964510876
#
# ['start', 'COMP_pol-int', 'SUBJ', 'end'] -21.054676488186836

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "Whether island, subject")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["Whether-subject"]*4)

# %% [markdown]
# ### 6. Whether island (comp_pol-int), object extraction (reported in the Appendix)

# %%
p_short_1, path1, un1 = get_prob(['OBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['OBJ'], freq_dist, n_gram)  # short island
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'OBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['COMP_pol-int', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'OBJ', 'end'] -1.9538277331986844
#
# ['start', 'OBJ', 'end'] -1.9538277331986844
#
# ['start', 'COMP_nominal', 'OBJ', 'end'] -12.927042247861705
#
# ['start', 'COMP_pol-int', 'OBJ', 'end'] -21.054676488186836

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "Whether island, object")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["Whether-object"]*4)

# %% [markdown]
# ### 7. Adjunct island

# %%
p_short_1, path1, un1 = get_prob(['SUBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['SUBJ'], freq_dist, n_gram)  # short island
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'OBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['ADJUNCT_adv', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'COMP_nominal', 'OBJ', 'end'] -12.927042247861705
#
# ['start', 'ADJUNCT_adv', 'OBJ', 'end'] -23.251901065523054

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "Adjunct island")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["Adjunct"]*4)

# %% [markdown]
# ### 8. RC island, object extraction, predlink as comparison

# %%
p_short_1, path1, un1 = get_prob(['SUBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['PREDLINK'], freq_dist, n_gram)  # short island
p_long_2, path4, un4 = get_prob(['ADJUNCT_rel', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'PREDLINK', 'end'] -4.014602815357906
#
# ['start', 'ADJUNCT_rel', 'OBJ', 'end'] -23.251901065523054

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "RC island, object")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["RC-predlink"]*4)

# %% [markdown]
# ### 9. RC island, subject extraction, subj as comparison

# %%
p_short_1, path1, un1 = get_prob(['SUBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['SUBJ'], freq_dist, n_gram)  # short island
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'SUBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['ADJUNCT_rel', 'SUBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'COMP_nominal', 'SUBJ', 'end'] -16.68241964510876
#
# ['start', 'ADJUNCT_rel', 'SUBJ', 'end'] -23.251901065523054

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "RC island, subject")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["RC-subject"]*4)

# %% [markdown]
# ## 10. RC island, P-comp extraction

# %%
p_short_1, path1, un1 = get_prob(['SUBJ'], freq_dist, n_gram)  # short no island
p_short_2, path2, un2 = get_prob(['SUBJ'], freq_dist, n_gram)  # short island
p_long_1, path3, un3 = get_prob(['COMP_nominal', 'ADJUNCT', 'OBJ'], freq_dist, n_gram)  # long no island
p_long_2, path4, un4 = get_prob(['ADJUNCT_rel', 'ADJUNCT', 'OBJ'], freq_dist, n_gram)  # long island
# Out:
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'SUBJ', 'end'] -1.2266393253777552
#
# ['start', 'COMP_nominal', 'ADJUNCT', 'OBJ', 'end'] -19.56599724870561
#
# ['start', 'ADJUNCT_rel', 'ADJUNCT', 'OBJ', 'end'] -26.36728028317723

# %%
plot_log_prob_simple(p_short_1, p_long_1, p_short_2, p_long_2, title = "RC island, P-comp")

# %%
paths.extend([" ".join(path1), " ".join(path2), " ".join(path3), " ".join(path4)])
probs.extend([p_short_1, p_short_2, p_long_1, p_long_2])
unattested.extend([un1, un2, un3, un4])
condition.extend(["RC-Pcomp"]*4)

# %%
structure = ["noIsland", "Island", "noIsland", "Island"]*10

# %%
distance = ["Short", "Short", "Long", "Long"]*10

# %%
dependency = ["RC"]*40
n_gram = ["Trigram"]*40

# %%
df = pd.DataFrame(list(zip(condition, distance, structure, paths, probs, unattested, dependency, n_gram)),
               columns =['condition', 'distance', 'structure', 'path', 'log_probability', 
                         'unattested_ngrams', 'dependency', 'n_gram'])

# %%
df.to_excel('../data/model_results_rc_trigrams.xlsx', index=False)

# %%
# All trigrams and their frequency
for key,value in sorted(freq_dist.items()):
    print(key,value)
# Out:
# ('ADJUNCT', 'OBJ', 'ADJUNCT') 1
# ('ADJUNCT', 'OBJ', 'end') 2483
# ('ADJUNCT', 'SUBJ', 'end') 24
# ('COMP', 'ADJUNCT', 'OBJ') 2
# ('COMP', 'OBJ', 'end') 15
# ('COMP', 'OBJ-BEN', 'end') 1
# ('COMP', 'OBL-TH', 'end') 4
# ('COMP', 'PREDLINK', 'end') 2
# ('COMP', 'XCOMP', 'OBJ') 2
# ('COMP_inf', 'ADJUNCT', 'OBJ') 13
# ('COMP_inf', 'OBJ', 'end') 19
# ('COMP_inf', 'OBL-TH', 'end') 5
# ('COMP_nominal', 'ADJUNCT', 'OBJ') 15
# ('COMP_nominal', 'ADJUNCT', 'SUBJ') 1
# ('COMP_nominal', 'COMP', 'OBL-TH') 1
# ('COMP_nominal', 'COMP_nominal', 'OBJ') 1
# ('COMP_nominal', 'COMP_nominal', 'XCOMP') 2
# ('COMP_nominal', 'OBJ', 'COMP') 1
# ('COMP_nominal', 'OBJ', 'end') 93
# ('COMP_nominal', 'OBJ-BEN', 'end') 1
# ('COMP_nominal', 'OBL-TH', 'end') 6
# ('COMP_nominal', 'PREDLINK', 'OBJ') 6
# ('COMP_nominal', 'PREDLINK', 'end') 42
# ('COMP_nominal', 'SUBJ', 'end') 15
# ('COMP_nominal', 'XCOMP', 'ADJUNCT') 11
# ('COMP_nominal', 'XCOMP', 'COMP_nominal') 1
# ('COMP_nominal', 'XCOMP', 'OBJ') 92
# ('COMP_nominal', 'XCOMP', 'OBJ-BEN') 2
# ('COMP_nominal', 'XCOMP', 'OBL-TH') 9
# ('COMP_nominal', 'XCOMP', 'PREDLINK') 11
# ('COMP_nominal', 'XCOMP', 'XCOMP') 7
# ('COMP_pol-int', 'OBJ', 'end') 1
# ('COMP_pol-int', 'SUBJ', 'end') 1
# ('COMP_pol-int', 'XCOMP', 'OBJ') 2
# ('COMP_pol-int', 'XCOMP', 'SUBJ') 1
# ('COMP_som', 'OBL-TH', 'end') 1
# ('COMP_wh-int', 'OBJ', 'end') 1
# ('COMP_wh-int', 'SUBJ', 'end') 23
# ('COMP_wh-int', 'XCOMP', 'OBJ') 1
# ('COMP_wh-int', 'XCOMP', 'OBL-TH') 1
# ('OBJ', 'ADJUNCT', 'OBJ') 3
# ('OBJ', 'COMP', 'OBJ') 11
# ('OBJ', 'COMP', 'OBJ-BEN') 1
# ('OBJ', 'COMP', 'OBL-TH') 1
# ('OBJ', 'COMP', 'PREDLINK') 2
# ('OBJ', 'OBJ', 'end') 1
# ('OBJ', 'OBJ-BEN', 'end') 1
# ('OBJ', 'OBL-TH', 'end') 31
# ('OBJ', 'SPEC', 'POSS') 2
# ('OBL-TH', 'SPEC', 'POSS') 1
# ('PREDLINK', 'ADJUNCT', 'OBJ') 66
# ('PREDLINK', 'COMP', 'OBJ') 3
# ('PREDLINK', 'COMP', 'XCOMP') 1
# ('PREDLINK', 'COMP_nominal', 'XCOMP') 1
# ('PREDLINK', 'OBJ', 'COMP') 1
# ('PREDLINK', 'OBJ', 'OBJ-BEN') 1
# ('PREDLINK', 'OBJ', 'end') 154
# ('PREDLINK', 'OBJ-BEN', 'end') 1
# ('PREDLINK', 'OBL-AG', 'end') 2
# ('PREDLINK', 'OBL-TH', 'end') 225
# ('PREDLINK', 'PREDLINK', 'end') 2
# ('PREDLINK', 'SUBJ', 'SPEC') 1
# ('PREDLINK', 'SUBJ', 'end') 4
# ('PREDLINK', 'XCOMP', 'OBJ') 3
# ('SPEC', 'POSS', 'end') 4
# ('SUBJ', 'SPEC', 'POSS') 1
# ('XCOMP', 'ADJUNCT', 'OBJ') 743
# ('XCOMP', 'ADJUNCT', 'SUBJ') 23
# ('XCOMP', 'ADJUNCT', 'end') 9
# ('XCOMP', 'COMP', 'ADJUNCT') 2
# ('XCOMP', 'COMP', 'OBJ') 1
# ('XCOMP', 'COMP', 'OBL-TH') 2
# ('XCOMP', 'COMP_nominal', 'ADJUNCT') 2
# ('XCOMP', 'COMP_nominal', 'OBJ') 12
# ('XCOMP', 'COMP_nominal', 'OBJ-BEN') 1
# ('XCOMP', 'COMP_nominal', 'OBL-TH') 1
# ('XCOMP', 'COMP_nominal', 'PREDLINK') 9
# ('XCOMP', 'COMP_nominal', 'SUBJ') 4
# ('XCOMP', 'COMP_nominal', 'XCOMP') 19
# ('XCOMP', 'COMP_nominal', 'end') 12
# ('XCOMP', 'COMP_wh-int', 'OBJ') 1
# ('XCOMP', 'COMP_wh-int', 'SUBJ') 3
# ('XCOMP', 'OBJ', 'ADJUNCT') 1
# ('XCOMP', 'OBJ', 'COMP') 7
# ('XCOMP', 'OBJ', 'OBJ') 1
# ('XCOMP', 'OBJ', 'OBL-TH') 9
# ('XCOMP', 'OBJ', 'SPEC') 1
# ('XCOMP', 'OBJ', 'end') 4758
# ('XCOMP', 'OBJ-BEN', 'end') 112
# ('XCOMP', 'OBL-AG', 'end') 7
# ('XCOMP', 'OBL-TH', 'SPEC') 1
# ('XCOMP', 'OBL-TH', 'end') 561
# ('XCOMP', 'PREDLINK', 'ADJUNCT') 9
# ('XCOMP', 'PREDLINK', 'COMP_nominal') 1
# ('XCOMP', 'PREDLINK', 'OBJ') 50
# ('XCOMP', 'PREDLINK', 'OBL-AG') 1
# ('XCOMP', 'PREDLINK', 'OBL-TH') 29
# ('XCOMP', 'PREDLINK', 'XCOMP') 1
# ('XCOMP', 'PREDLINK', 'end') 220
# ('XCOMP', 'SUBJ', 'end') 4755
# ('XCOMP', 'XCOMP', 'ADJUNCT') 54
# ('XCOMP', 'XCOMP', 'COMP_nominal') 3
# ('XCOMP', 'XCOMP', 'OBJ') 212
# ('XCOMP', 'XCOMP', 'OBJ-BEN') 9
# ('XCOMP', 'XCOMP', 'OBL-TH') 33
# ('XCOMP', 'XCOMP', 'PREDLINK') 12
# ('XCOMP', 'XCOMP', 'SUBJ') 60
# ('XCOMP', 'XCOMP', 'XCOMP') 7
# ('start', 'ADJUNCT', 'OBJ') 1642
# ('start', 'ADJUNCT', 'end') 611
# ('start', 'COMP', 'XCOMP') 1
# ('start', 'COMP_inf', 'ADJUNCT') 13
# ('start', 'COMP_inf', 'OBJ') 19
# ('start', 'COMP_inf', 'OBL-TH') 5
# ('start', 'COMP_nominal', 'ADJUNCT') 14
# ('start', 'COMP_nominal', 'COMP') 1
# ('start', 'COMP_nominal', 'COMP_nominal') 3
# ('start', 'COMP_nominal', 'OBJ') 81
# ('start', 'COMP_nominal', 'OBL-TH') 5
# ('start', 'COMP_nominal', 'PREDLINK') 39
# ('start', 'COMP_nominal', 'SUBJ') 11
# ('start', 'COMP_nominal', 'XCOMP') 111
# ('start', 'COMP_pol-int', 'OBJ') 1
# ('start', 'COMP_pol-int', 'SUBJ') 1
# ('start', 'COMP_pol-int', 'XCOMP') 3
# ('start', 'COMP_som', 'OBL-TH') 1
# ('start', 'COMP_wh-int', 'SUBJ') 20
# ('start', 'COMP_wh-int', 'XCOMP') 2
# ('start', 'OBJ', 'ADJUNCT') 1
# ('start', 'OBJ', 'COMP') 6
# ('start', 'OBJ', 'OBL-TH') 22
# ('start', 'OBJ', 'SPEC') 1
# ('start', 'OBJ', 'end') 7934
# ('start', 'OBJ-BEN', 'end') 104
# ('start', 'OBL-TH', 'end') 1028
# ('start', 'PREDLINK', 'ADJUNCT') 57
# ('start', 'PREDLINK', 'COMP') 4
# ('start', 'PREDLINK', 'OBJ') 100
# ('start', 'PREDLINK', 'OBJ-BEN') 1
# ('start', 'PREDLINK', 'OBL-AG') 1
# ('start', 'PREDLINK', 'OBL-TH') 196
# ('start', 'PREDLINK', 'PREDLINK') 2
# ('start', 'PREDLINK', 'SUBJ') 5
# ('start', 'PREDLINK', 'XCOMP') 2
# ('start', 'PREDLINK', 'end') 1010
# ('start', 'SUBJ', 'end') 16418
# ('start', 'XCOMP', 'ADJUNCT') 710
# ('start', 'XCOMP', 'COMP') 5
# ('start', 'XCOMP', 'COMP_nominal') 56
# ('start', 'XCOMP', 'COMP_wh-int') 4
# ('start', 'XCOMP', 'OBJ') 4465
# ('start', 'XCOMP', 'OBJ-BEN') 101
# ('start', 'XCOMP', 'OBL-AG') 7
# ('start', 'XCOMP', 'OBL-TH') 519
# ('start', 'XCOMP', 'PREDLINK') 288
# ('start', 'XCOMP', 'SUBJ') 4694
# ('start', 'XCOMP', 'XCOMP') 376
# ('start', 'XCOMP', 'end') 1
